# %%
import pandas as pd
import numpy as np

# %%
mezcal = pd.read_csv('./poverty/mezcal_11800.csv')
appellation = pd.read_csv('./poverty/mezcal appellation of origin_326.csv')
denominacion = pd.read_csv('./poverty/mezcal denominacion de origen_2260.csv')
desarrollo = pd.read_csv('./poverty/mezcal desarrollo_7360.csv')
desarrollo_oax = pd.read_csv('./poverty/mezcal desarrollo oaxaca_3180.csv')
development = pd.read_csv('./poverty/mezcal development_4630.csv')
development_oax = pd.read_csv('./poverty/mezcal development oaxaca_1810.csv')
poberty = pd.read_csv('./poverty/mezcal poverty_945.csv')
poverty_oax = pd.read_csv('./poverty/mezcal poverty oaxaca_496.csv')
pobreza = pd.read_csv('./poverty/mezcal pobreza_3570.csv')
pobreza_oax = pd.read_csv('./poverty/mezcal pobreza oaxaca_1680.csv')

# %%
mezcal_titles = pd.DataFrame(mezcal["Title"]) 
appellation_titles = pd.DataFrame(mezcal["Title"]) 
denominacion_titles = pd.DataFrame(mezcal["Title"]) 
desarrollo_titles = pd.DataFrame(mezcal["Title"]) 
desarrollo_oax_titles = pd.DataFrame(mezcal["Title"]) 
development_titles = pd.DataFrame(mezcal["Title"]) 
development_oax_titles = pd.DataFrame(mezcal["Title"]) 
poberty = pd.DataFrame(mezcal["Title"]) 
poverty_oax_titles = pd.DataFrame(mezcal["Title"]) 
pobreza_titles = pd.DataFrame(mezcal["Title"]) 
pobreza_oax_titles = pd.DataFrame(mezcal["Title"])

# %% [markdown]
# ### get language table

# %%
lang_table = pd.read_html('https://en.wikipedia.org/wiki/List_of_ISO_639-1_codes')[1]

# %%
lang_table.drop(['Language family', 'Language family.1', 'Native name (endonym)', '639-2/T', '639-2/B', '639-3', 'Notes'], axis = 1, inplace=True)

# %% [markdown]
# ## Identify language
#
# langdetect supports 55 languages out of the box (ISO 639-1 codes)
#
# https://github.com/Mimino666/langdetect

# %%
from langdetect import detect

# %%
mezcal_titles_iso_abr = [detect(e) for e in mezcal_titles['Title']]
appellation_titles_iso_abr = [detect(e) for e in appellation_titles['Title']]
denominacion_titles_iso_abr = [detect(e) for e in denominacion_titles['Title']]
desarrollo_titles_iso_abr = [detect(e) for e in desarrollo_titles['Title']]
desarrollo_oax_titles_iso_abr = [detect(e) for e in desarrollo_oax_titles['Title']]
development_titles_iso_abr = [detect(e) for e in development_titles['Title']]
development_oax_titles_iso_abr = [detect(e) for e in development_oax_titles['Title']]
poberty_iso_abr = [detect(e) for e in poberty['Title']]
poverty_oax_titles_iso_abr = [detect(e) for e in poverty_oax_titles['Title']]
pobreza_titles_iso_abr = [detect(e) for e in pobreza_titles['Title']]
pobreza_oax_titles_iso_abr = [detect(e) for e in pobreza_oax_titles['Title']]

# %%
mezcal_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in mezcal_titles_iso_abr]
appellation_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in appellation_titles_iso_abr]
denominacion_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in denominacion_titles_iso_abr]
desarrollo_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in desarrollo_titles_iso_abr]
desarrollo_oax_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in desarrollo_oax_titles_iso_abr]
development_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in development_titles_iso_abr]
development_oax_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in development_oax_titles_iso_abr]
poberty['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in poberty_iso_abr]
poverty_oax_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in poverty_oax_titles_iso_abr]
pobreza_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in pobreza_titles_iso_abr]
pobreza_oax_titles['Language'] = [lang_table[lang_table['639-1'] == element]['ISO language name'].values for element in pobreza_oax_titles_iso_abr]

# %%
todos = [
    mezcal_titles,
    appellation_titles,
    denominacion_titles,
    desarrollo_titles,
    desarrollo_oax_titles,
    development_titles,
    development_oax_titles,
    poberty,
    poverty_oax_titles,
    pobreza_titles,
    pobreza_oax_titles,
]

# %% [markdown]
# ## language count and plot

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
todos[0]['Language'].value_counts().to_csv('pobreza_oax.csv')

# %%
todos[0]['Language'].value_counts()
# Out:
# [Spanish, Castilian]               463
# [English]                          397
# [German]                            50
# [Portuguese]                        18
# [Catalan, Valencian]                14
# [French]                             9
# [Italian]                            8
# [Romanian, Moldavian, Moldovan]      7
# [Croatian]                           3
# [Estonian]                           3
# [Somali]                             3
# [Swahili]                            2
# [Tagalog]                            2
# [Vietnamese]                         1
# [Turkish]                            1
# [Hungarian]                          1
# [Lithuanian]                         1
# [Finnish]                            1
# [Norwegian]                          1
# [Indonesian]                         1
# [Welsh]                              1
# []                                   1
# [Russian]                            1
# [Korean]                             1
# ...

# %%
ax = todos[0]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[1]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Appellation of Origin results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[2]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Denominacion de Origen results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[3]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal y desarrollo results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[4]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal y desarrollo Oaxaca results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[5]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal development results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")



development_oax = pd.read_csv('./poverty/mezcal development oaxaca_1810.csv')
poberty = pd.read_csv('./poverty/mezcal poverty_945.csv')
poverty_oax = pd.read_csv('./poverty/mezcal poverty oaxaca_496.csv')
pobreza = pd.read_csv('./poverty/mezcal pobreza_3570.csv')
pobreza_oax = pd.read_csv('./poverty/mezcal pobreza oaxaca_1680.csv')

# %% [markdown]
# tokenizing

# %%
ax = todos[6]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal development Oaxaca results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")




poberty = pd.read_csv('./poverty/mezcal poverty_945.csv')
poverty_oax = pd.read_csv('./poverty/mezcal poverty oaxaca_496.csv')
pobreza = pd.read_csv('./poverty/mezcal pobreza_3570.csv')
pobreza_oax = pd.read_csv('./poverty/mezcal pobreza oaxaca_1680.csv')

# %% [markdown]
# filter stopwords

# %%
ax = todos[7]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal poverty results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[8]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal poverty Oaxaca results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = todos[9]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal pobreza results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")




pobreza_oax = pd.read_csv('./poverty/mezcal pobreza oaxaca_1680.csv')

# %%
ax = todos[10]['Language'].value_counts().plot(kind='bar',
                                    figsize=(8,8),
                                    title="Mezcal pobreza Oaxaca results by language")
ax.set_xlabel("Language")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
accented_string = u'Málaga'
# accented_string is of type 'unicode'
import unidecode
unaccented_string = unidecode.unidecode(accented_string)
# unaccented_string contains 'Malaga'and is of type 'str'

# %%
import unicodedata
def strip_accents(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

# %%
# import required module
import unidecode
 
# assign string
stringList = ["hell°",  "tromsø",  "stävänger", "ölut"]
 
# display original string
print('\nOriginal List of Strings:\n', stringList)
 
for i in range(len(stringList)):
    # remove ascents
    stringList[i] = unidecode.unidecode(stringList[i])
 
# display new string
print('\nNew List of Strings:\n', stringList)

# %%
import re
import unicodedata

def strip_accents(text):
    """
    Strip accents from input String.

    :param text: The input string.
    :type text: String.

    :returns: The processed String.
    :rtype: String.
    """
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    return str(text)

def text_to_id(text):
    """
    Convert input text to id.

    :param text: The input string.
    :type text: String.

    :returns: The processed String.
    :rtype: String.
    """
    text = strip_accents(text.lower())
    text = re.sub('[ ]+', '_', text)
    text = re.sub('[^0-9a-zA-Z_-]', '', text)
    return text

# %%
# Python3 code to demonstrate working of
# Removing punctuations in string
# Using loop + punctuation string
 
# initializing string
test_str = "Gfg, is best : for ! Geeks ;"
 
# printing original string
print("The original string is : " + test_str)
 
# initializing punctuations string
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
 
# Removing punctuations in string
# Using loop + punctuation string
for ele in test_str:
    if ele in punc:
        test_str = test_str.replace(ele, "")
 
# printing result
print("The string after punctuation filter : " + test_str)

# %%
# Python3 code to demonstrate working of
# Removing punctuations in string
# Using regex
import re
 
# initializing string
test_str = "Gfg, is best : for ! Geeks ;"
 
# printing original string
print("The original string is : " + test_str)
 
# Removing punctuations in string
# Using regex
res = re.sub(r'[^\w\s]', '', test_str)
 
# printing result
print("The string after punctuation filter : " + res)
